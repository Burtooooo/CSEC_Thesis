# %%
from google import genai
import re

# %%
sentiment_prompt = "You will be given a news article about a company with publicly traded stock. This article has just been released and the information is likely newly released to the public. Please give a score on a continuous scale from -1 to 1 rating the sentiment of the news. -1 indicates the most negative sentiment while 1 indicates the most positive and a score of 0 indicates neutral sentiment. Please respond with only your numerical score. Here is the beginning of the article: "
surprise_prompt = "You will be given a news article about a company with publicly traded stock. This article has just been released and the information is likely newly released to the public. Please give a score on a continuous scale from -1 to 1 rating how surprising you believe the news to be. -1 indicates the least surprising news, as in news that is probably well expected and accounted for by the public, while 1 indicates the most surprising news. A score of 0 indicates averagely surprising news. Please respond with only your numerical score. Here is the beginning of the article: "
important_prompt = "You will be given a news article about a company with publicly traded stock. This article has just been released and the information is likely newly released to the public. Please give a score on a continuous scale from -1 to 1 rating how important you believe the news to be. -1 indicates the least important news while 1 indicates the most important news. A score of 0 indicates averagely important news. Please respond with only your numerical score. Here is the beginning of the article: "
price_prompt = "You will be given a news article about a company with publicly traded stock. This article has just been released and the information is likely newly released to the public. Please give a score on a continuous scale from -1 to 1 rating how you expect the price of the stock to move following the news. -1 indicates the highest probability of a downward price movement, while 1 indicates the highest probability of upward price movement. A score of 0 indicates you do not anticipate the price to move in either direction. Please respond with only your numerical score. Here is the beginning of the article: "

# %%
print(sentiment_prompt)
print(surprise_prompt)
print(important_prompt)
print(price_prompt)
# Out:
# You will be given a news article about a company with publicly traded stock. This article has just been released and the information is likely newly released to the public. Please give a score on a continuous scale from -1 to 1 rating the sentiment of the news. -1 indicates the most negative sentiment while 1 indicates the most positive and a score of 0 indicates neutral sentiment. Please respond with only your numerical score. Here is the beginning of the article:
# ...

# %%
import csv
from datetime import datetime
import calendar
import requests
import time
import ast
from polygon.rest import RESTClient

client = genai.Client(api_key="AIzaSyCGtnUP1xlSNpMXlQwM0AxrDYFR2NnTYD4")

with open('ProcessedTitanData2.csv', newline='') as csvfile:
  quoter = list(csv.reader(csvfile, delimiter=','))
  for i in range(0, len(quoter)):
    # try:
        buffer = quoter[i]
        text = buffer[-1]
        #print(buffer)
        prompt1 = sentiment_prompt + text
        prompt2 = surprise_prompt + text
        prompt3 = important_prompt + text
        prompt4 = price_prompt + text
        response1 = client.models.generate_content(
        model="gemini-2.0-flash", contents=prompt1)
        clean1 = re.findall(r'[+-]?\d+(?:\.\d+)?', response1.text)
        buffer.append(float(clean1[0]))

        response2 = client.models.generate_content(
        model="gemini-2.0-flash", contents=prompt2)
        clean2 = re.findall(r'[+-]?\d+(?:\.\d+)?', response2.text)
        buffer.append(float(clean2[0]))

        response3 = client.models.generate_content(
        model="gemini-2.0-flash", contents=prompt3)
        clean3 = re.findall(r'[+-]?\d+(?:\.\d+)?', response3.text)
        buffer.append(float(clean3[0]))

        response4 = client.models.generate_content(
        model="gemini-2.0-flash", contents=prompt4)
        clean4 = re.findall(r'[+-]?\d+(?:\.\d+)?', response4.text)
        buffer.append(float(clean4[0]))

        with open('PostGeminiData2.csv', 'a', newline='') as csvfilewrite:
                #print(quoter[i][0] + " YAY")
            cleaner = csv.writer(csvfilewrite, delimiter=',')
            cleaner.writerow(buffer)
            csvfilewrite.close()
    # except:
    #     print("WOAH FAILED FOR SOME REASON")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 22
#      20 prompt3 = important_prompt + text
#      21 prompt4 = price_prompt + text
# ---> 22 response1 = client.models.generate_content(
#      23 model="gemini-2.0-flash", contents=prompt1)
#      24 clean1 = re.findall(r'[+-]?\d+(?:\.\d+)?', response1.text)
#      25 buffer.append(float(clean1[0]))
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/google/genai/models.py:5019, in Models.generate_content(self, model, contents, config)
#    5017 while remaining_remote_calls_afc > 0:
#    5018   i += 1
# -> 5019   response = self._generate_content(
#    5020       model=model, contents=contents, config=config
#    5021   )
#    5022   logger.info(f'AFC remote call {i} is done.')
#    5023   remaining_remote_calls_afc -= 1
#
# ...

# %%
client = genai.Client(api_key="AIzaSyCGtnUP1xlSNpMXlQwM0AxrDYFR2NnTYD4")

for i in range(10):
    response = client.models.generate_content(
        model="gemini-2.0-flash", contents="Explain how AI works in a few words"
    )
    print(response.text)
# Out:
# AI learns from data to make predictions or decisions.
#
# AI learns patterns from data to make predictions or decisions.
#
# AI works by learning patterns from data to make predictions or decisions.
#
# AI uses algorithms to learn from data and make decisions.
#
# AI learns patterns from data to make predictions or decisions.
#
# AI learns from data to make decisions or predictions.
#
# AI learns patterns from data to make predictions or decisions.
#
# AI learns patterns from data to make predictions or decisions.
#
# AI learns from data to make decisions.
#
# AI learns patterns from data to make predictions or decisions.
